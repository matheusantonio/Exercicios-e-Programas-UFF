# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#Insira aqui o nome da imagem usada no programa em C que você deseja analisar.
imgNome = "imagem"

# %%
df = pd.read_csv('tabelas\\zip_quen-eng.csv', index_col='bit').sort_index()

# %%
df
# Out:
#        quantidade
# bit
# 0              17
# 1               4
# 3               4
# 4               1
# 6               4
# 7               2
# 8               2
# 10              3
# 12              4
# 13              1
# 17              1
# 20              2
# 21              1
# 24              2
# 26              1
# 27              3
# 28              1
# 29              1
# 30              1
# 32              3
# 33              1
# 35              2
# 36              1
# 38              1
# 39              2
# 43              2
# 44              2
# 46              1
# 49              3
# 53              3
# ...           ...
# 65506           1
# 65507           6
# 65508           3
# 65509           6
# 65510           4
# 65511           6
# 65512           5
# 65513           5
# 65514           2
# 65515           8
# 65516           8
# 65517           6
# 65518           3
# 65519          12
# 65520           1
# 65521           5
# 65522           7
# 65523           5
# 65524           2
# 65525           4
# 65526           3
# 65527           6
# 65528           5
# 65529           5
# 65530           9
# 65531           7
# 65532           6
# 65533           4
# 65534           4
# 65535          12
#
# [60994 rows x 1 columns]

# %%
df.plot(figsize=(15, 5), title='Quantidade de bits')
