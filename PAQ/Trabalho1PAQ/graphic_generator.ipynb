# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#Insira aqui o nome da imagem usada no programa em C que você deseja analisar.
imgNome = "imagem"

# %%
df = pd.read_csv('tabelas\\video.csv', index_col='bit').sort_index()
dfzip = pd.read_csv('tabelas\\zip_video.csv', index_col='bit').sort_index()

# %%
dfzip.head()
# Out:
#      quantidade
# bit
# 0           978
# 1           298
# 2            67
# 3            56
# 4            63

# %%
df.plot(figsize=(15, 5), title='Quantidade de bits')
dfzip.plot(figsize=(15, 5), title='Quantidade de bits (zipado)')

# %%
df.sort_values(by='quantidade', ascending=False).head()
# Out:
#        quantidade
# bit
# 0           18838
# 12592        4715
# 25207        4715
# 16           2494
# 25444        2431
