# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#Insira aqui o nome da imagem usada no programa em C que você deseja analisar.
imgNome = "zip_imagem"

# %%
df = pd.read_csv('tabelas\\' + imgNome + '.csv', index_col='bit').sort_index()

# %%
df2 = pd.read_csv('tabelas\\imagem.csv', index_col='bit').sort_index()

# %%
df.plot(figsize=(15, 5), title='Quantidade de bits')
#plt.savefig('plots\\' + imgNome + '.png')
df2.plot(figsize=(15, 5), title='Quantidade de bits')

# %%
df.sort_values('quantidade', ascending=False).head()
# Out:
#        quantidade
# bit
# 0              20
# 32425           5
# 9578            5
# 16499           5
# 51688           4

# %%
df2.sort_values('quantidade', ascending=False).head()
# Out:
#       quantidade
# bit
# 0            177
# 255          120
# 7710          26
# 256           13
# 512           11

# %%
arq = open('arquivo.txt', 'r')

# %%
img = arq.read().split('.')[0]

# %%
print(img)
# Out:
# imagem

# %%
arq.close()

# %%
df = pd.read_csv('tabelas\\' + img + '.csv', index_col='bit').sort_index()

# %%
df.plot(figsize=(15, 5), title='Quantidade de bits')
